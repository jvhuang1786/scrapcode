# %%
import os
import glob
os.environ["KERAS_BACKEND"] = "tensorflow"
import numpy as np
from sklearn.utils import shuffle
import time
import cv2
import scipy
from PIL import Image
import matplotlib.gridspec as gridspec
from keras.layers import Dense
from keras.layers import Reshape
from keras.layers.core import Activation
from keras.layers.normalization import BatchNormalization
from keras.layers.convolutional import UpSampling2D
from keras.layers.pooling import MaxPooling2D
from keras.layers.core import Flatten
from keras.layers import Conv2D, Conv2DTranspose, Dropout
from keras.models import Model
from keras.optimizers import SGD, Adam, RMSprop
from keras.layers.advanced_activations import LeakyReLU
import matplotlib.pyplot as plt
from keras.models import load_model
from keras.utils.vis_utils import plot_model
import keras.backend as K
#from scipy.interpolate import spline
K.set_image_dim_ordering('tf')
import numpy as np
from sklearn.utils import shuffle
import tensorflow as tf
from keras.backend.tensorflow_backend import set_session
from keras.layers import Input, merge
from keras.initializers import RandomNormal
K.set_image_dim_ordering('tf')
config = tf.ConfigProto()
config.gpu_options.allow_growth = True 
set_session(tf.Session(config=config))
from collections import deque
# Out:
# Using TensorFlow backend.

# %%
filenames = glob.glob('data/*.png')

print("Num_Images: ",len(filenames))
# Out:
# Num_Images:  21551

# %%
plt.figure(figsize=(10, 8))
for i in range(5):
    img = plt.imread(filenames[i], 0)
    plt.subplot(4, 5, i+1)
    plt.imshow(img)
    plt.title(img.shape)
    plt.xticks([])
    plt.yticks([])
plt.tight_layout()
plt.show()

# %%
# A function to normalize image pixels.
def norm_img(img):
    '''A function to Normalize Images.
    Input:
        img : Original image as numpy array.
    Output: Normailized Image as numpy array
    '''
    img = (img / 127.5) - 1
    return img

def denorm_img(img):
    '''A function to Denormailze, i.e. recreate image from normalized image
    Input:
        img : Normalized image as numpy array.
    Output: Original Image as numpy array
    '''
    img = (img + 1) * 127.5
    return img.astype(np.uint8) 

def sample_from_dataset(batch_size, image_shape, data_dir=None):
    '''Create a batch of image samples by sampling random images from a data directory.
    Resizes the image using image_shape and normalize the images.
    Input:
        batch_size : Sample size required
        image_size : Size that Image should be resized to
        data_dir : Path of directory where training images are placed.

    Output:
        sample : batch of processed images 
    '''
    sample_dim = (batch_size,) + image_shape
    sample = np.empty(sample_dim, dtype=np.float32)
    all_data_dirlist = list(glob.glob(data_dir))
    sample_imgs_paths = np.random.choice(all_data_dirlist,batch_size)
    for index,img_filename in enumerate(sample_imgs_paths):
        image = Image.open(img_filename)
        image = image.resize(image_shape[:-1])
        image = image.convert('RGB') 
        image = np.asarray(image)
        image = norm_img(image)
        sample[index,...] = image
    return sample

# %%
def gen_noise(batch_size, noise_shape):
    ''' Generates a numpy vector sampled from normal distribution of shape (batch_size,noise_shape)
    Input:
        batch_size : size of batch
        noise_shape: shape of noise vector, normally kept as 100 
    Output:a numpy vector sampled from normal distribution of shape (batch_size,noise_shape)     
    '''
    return np.random.normal(0, 1, size=(batch_size,)+noise_shape)

# %%
def get_gen_normal(noise_shape):
    ''' This function takes as input shape of the noise vector and creates the Keras generator    architecture.
    '''
    kernel_init = 'glorot_uniform'    
    gen_input = Input(shape = noise_shape) 
    
    # Transpose 2D conv layer 1. 
    generator = Conv2DTranspose(filters = 512, kernel_size = (4,4), strides = (1,1), padding = "valid", data_format = "channels_last", kernel_initializer = kernel_init)(gen_input)
    generator = BatchNormalization(momentum = 0.5)(generator)
    generator = LeakyReLU(0.2)(generator)
    
    # Transpose 2D conv layer 2.
    generator = Conv2DTranspose(filters = 256, kernel_size = (4,4), strides = (2,2), padding = "same", data_format = "channels_last", kernel_initializer = kernel_init)(generator)
    generator = BatchNormalization(momentum = 0.5)(generator)
    generator = LeakyReLU(0.2)(generator)
    
    # Transpose 2D conv layer 3.
    generator = Conv2DTranspose(filters = 128, kernel_size = (4,4), strides = (2,2), padding = "same", data_format = "channels_last", kernel_initializer = kernel_init)(generator)
    generator = BatchNormalization(momentum = 0.5)(generator)
    generator = LeakyReLU(0.2)(generator)
    
    # Transpose 2D conv layer 4.
    generator = Conv2DTranspose(filters = 64, kernel_size = (4,4), strides = (2,2), padding = "same", data_format = "channels_last", kernel_initializer = kernel_init)(generator)
    generator = BatchNormalization(momentum = 0.5)(generator)
    generator = LeakyReLU(0.2)(generator)
    
    # conv 2D layer 1.
    generator = Conv2D(filters = 64, kernel_size = (3,3), strides = (1,1), padding = "same", data_format = "channels_last", kernel_initializer = kernel_init)(generator)
    generator = BatchNormalization(momentum = 0.5)(generator)
    generator = LeakyReLU(0.2)(generator)
    
    # Final Transpose 2D conv layer 5 to generate final image. Filter size 3 for 3 image channel
    generator = Conv2DTranspose(filters = 3, kernel_size = (4,4), strides = (2,2), padding = "same", data_format = "channels_last", kernel_initializer = kernel_init)(generator)
    
    # Tanh activation to get final normalized image
    generator = Activation('tanh')(generator)
    
    # defining the optimizer and compiling the generator model.
    gen_opt = Adam(lr=0.00015, beta_1=0.5)
    generator_model = Model(input = gen_input, output = generator)
    generator_model.compile(loss='binary_crossentropy', optimizer=gen_opt, metrics=['accuracy'])
    generator_model.summary()
    return generator_model

# %%
def get_disc_normal(image_shape=(64,64,3)):
    dropout_prob = 0.4
    kernel_init = 'glorot_uniform'
    dis_input = Input(shape = image_shape)
    
    # Conv layer 1:
    discriminator = Conv2D(filters = 64, kernel_size = (4,4), strides = (2,2), padding = "same", data_format = "channels_last", kernel_initializer = kernel_init)(dis_input)
    discriminator = LeakyReLU(0.2)(discriminator)
    # Conv layer 2:
    discriminator = Conv2D(filters = 128, kernel_size = (4,4), strides = (2,2), padding = "same", data_format = "channels_last", kernel_initializer = kernel_init)(discriminator)
    discriminator = BatchNormalization(momentum = 0.5)(discriminator)
    discriminator = LeakyReLU(0.2)(discriminator)
    # Conv layer 3:   
    discriminator = Conv2D(filters = 256, kernel_size = (4,4), strides = (2,2), padding = "same", data_format = "channels_last", kernel_initializer = kernel_init)(discriminator)
    discriminator = BatchNormalization(momentum = 0.5)(discriminator)
    discriminator = LeakyReLU(0.2)(discriminator)
    # Conv layer 4:
    discriminator = Conv2D(filters = 512, kernel_size = (4,4), strides = (2,2), padding = "same", data_format = "channels_last", kernel_initializer = kernel_init)(discriminator)
    discriminator = BatchNormalization(momentum = 0.5)(discriminator)
    discriminator = LeakyReLU(0.2)(discriminator)#discriminator = MaxPooling2D(pool_size=(2, 2))(discriminator)
    # Flatten
    discriminator = Flatten()(discriminator)
    # Dense Layer
    discriminator = Dense(1)(discriminator)
    # Sigmoid Activation
    discriminator = Activation('sigmoid')(discriminator)
    # Optimizer and Compiling model
    dis_opt = Adam(lr=0.0002, beta_1=0.5)
    discriminator_model = Model(input = dis_input, output = discriminator)
    discriminator_model.compile(loss='binary_crossentropy', optimizer=dis_opt, metrics=['accuracy'])
    discriminator_model.summary()
    return discriminator_model

# %%
# !mkdir images
# Out:
# mkdir: images: File exists

# %%
# Shape of noise vector to be input to the Generator
noise_shape = (1,1,100)
# Number of steps for training. num_epochs = num_steps*batch_size/data_size
num_steps = 50000
# batch size for training.
batch_size = 64
# Location to save images and logs 
img_save_dir = "images"
# Image size to reshape to
image_shape = (64,64,3)
# Location of data directory
data_dir = "data/*.png"
# set up log and save directories
log_dir = img_save_dir
save_model_dir = img_save_dir

# %%
def save_img_batch(img_batch,img_save_dir):
    '''Takes as input a image batch and a img_save_dir and saves 16 images from the batch in a 4x4 grid in the img_save_dir
    '''
    plt.figure(figsize=(16,16))
    gs1 = gridspec.GridSpec(4, 4)
    gs1.update(wspace=0, hspace=0)
    rand_indices = np.random.choice(img_batch.shape[0],16,replace=False)
    for i in range(16):
        ax1 = plt.subplot(gs1[i])
        ax1.set_aspect('equal')
        rand_index = rand_indices[i]
        image = img_batch[rand_index, :,:,:]
        fig = plt.imshow(denorm_img(image))
        plt.axis('off')
        fig.axes.get_xaxis().set_visible(False)
        fig.axes.get_yaxis().set_visible(False)
    plt.tight_layout()
    plt.savefig(img_save_dir,bbox_inches='tight',pad_inches=0)
    plt.show()

# %%
discriminator = get_disc_normal(image_shape)
generator = get_gen_normal(noise_shape)
# Out:
# WARNING:tensorflow:From /Users/justin/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# /Users/justin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("ac...)`
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 64, 64, 3)         0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 32, 32, 64)        3136
# _________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)    (None, 32, 32, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 16, 16, 128)       131200
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 16, 16, 128)       512
# _________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)    (None, 16, 16, 128)       0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 8, 8, 256)         524544
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 8, 8, 256)         1024
# _________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)    (None, 8, 8, 256)         0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 4, 4, 512)         2097664
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 4, 4, 512)         2048
# _________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)    (None, 4, 4, 512)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 8192)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 8193
# _________________________________________________________________
# activation_1 (Activation)    (None, 1)                 0
# =================================================================
# Total params: 2,768,321
# Trainable params: 2,766,529
# Non-trainable params: 1,792
# _________________________________________________________________
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         (None, 1, 1, 100)         0
# _________________________________________________________________
# conv2d_transpose_1 (Conv2DTr (None, 4, 4, 512)         819712
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 4, 4, 512)         2048
# _________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)    (None, 4, 4, 512)         0
# _________________________________________________________________
# conv2d_transpose_2 (Conv2DTr (None, 8, 8, 256)         2097408
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 8, 8, 256)         1024
# _________________________________________________________________
# leaky_re_lu_6 (LeakyReLU)    (None, 8, 8, 256)         0
# _________________________________________________________________
# conv2d_transpose_3 (Conv2DTr (None, 16, 16, 128)       524416
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 16, 16, 128)       512
# _________________________________________________________________
# leaky_re_lu_7 (LeakyReLU)    (None, 16, 16, 128)       0
# _________________________________________________________________
# conv2d_transpose_4 (Conv2DTr (None, 32, 32, 64)        131136
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 32, 32, 64)        256
# _________________________________________________________________
# leaky_re_lu_8 (LeakyReLU)    (None, 32, 32, 64)        0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 32, 32, 64)        36928
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 32, 32, 64)        256
# _________________________________________________________________
# leaky_re_lu_9 (LeakyReLU)    (None, 32, 32, 64)        0
# _________________________________________________________________
# conv2d_transpose_5 (Conv2DTr (None, 64, 64, 3)         3075
# _________________________________________________________________
# activation_2 (Activation)    (None, 64, 64, 3)         0
# =================================================================
# Total params: 3,616,771
# Trainable params: 3,614,723
# Non-trainable params: 2,048
# _________________________________________________________________
# /Users/justin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:40: UserWarning: Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("ac...)`

# %%
discriminator.trainable = False

# Optimizer for the GAN
opt = Adam(lr=0.00015, beta_1=0.5) #same as generator
# Input to the generator
gen_inp = Input(shape=noise_shape)

GAN_inp = generator(gen_inp)
GAN_opt = discriminator(GAN_inp)

# Final GAN
gan = Model(input = gen_inp, output = GAN_opt)
gan.compile(loss = 'binary_crossentropy', optimizer = opt, metrics=['accuracy'])
# Out:
# /Users/justin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:12: UserWarning: Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("mo...)`
#   if sys.path[0] == '':

# %%
# Use a fixed noise vector to see how the GAN Images transition through time on a fixed noise. 
fixed_noise = gen_noise(16,noise_shape)

# To keep Track of losses
avg_disc_fake_loss = []
avg_disc_real_loss = []
avg_GAN_loss = []

# We will run for num_steps iterations
for step in range(num_steps): 
    tot_step = step
    print("Begin step: ", tot_step)
    # to keep track of time per step
    step_begin_time = time.time() 
    
    # sample a batch of normalized images from the dataset
    real_data_X = sample_from_dataset(batch_size, image_shape, data_dir=data_dir)
    
    # Genearate noise to send as input to the generator
    noise = gen_noise(batch_size,noise_shape)
    
    # Use generator to create(predict) images
    fake_data_X = generator.predict(noise)
    
    # Save predicted images from the generator every 10th step
    if (tot_step % 100) == 0:
        step_num = str(tot_step).zfill(4)
        save_img_batch(fake_data_X,img_save_dir+step_num+"_image.png")
    
    # Create the labels for real and fake data. We don't give exact ones and zeros but add a small amount of noise. This is an important GAN training trick
    real_data_Y = np.ones(batch_size) - np.random.random_sample(batch_size)*0.2
    fake_data_Y = np.random.random_sample(batch_size)*0.2
        
    # train the discriminator using data and labels

    discriminator.trainable = True
    generator.trainable = False

    # Training Discriminator seperately on real data
    dis_metrics_real = discriminator.train_on_batch(real_data_X,real_data_Y) 
    # training Discriminator seperately on fake data
    dis_metrics_fake = discriminator.train_on_batch(fake_data_X,fake_data_Y) 
    
    print("Disc: real loss: %f fake loss: %f" % (dis_metrics_real[0], dis_metrics_fake[0]))
    
    # Save the losses to plot later
    avg_disc_fake_loss.append(dis_metrics_fake[0])
    avg_disc_real_loss.append(dis_metrics_real[0])
    
    # Train the generator using a random vector of noise and its labels (1's with noise)
    generator.trainable = True
    discriminator.trainable = False

    GAN_X = gen_noise(batch_size,noise_shape)
    GAN_Y = real_data_Y
   
    gan_metrics = gan.train_on_batch(GAN_X,GAN_Y)
    print("GAN loss: %f" % (gan_metrics[0]))
    
    # Log results by opening a file in append mode
    text_file = open(log_dir+"\\training_log.txt", "a")
    text_file.write("Step: %d Disc: real loss: %f fake loss: %f GAN loss: %f\n" % (tot_step, dis_metrics_real[0], dis_metrics_fake[0],gan_metrics[0]))
    text_file.close()

    # save GAN loss to plot later
    avg_GAN_loss.append(gan_metrics[0])
            
    end_time = time.time()
    diff_time = int(end_time - step_begin_time)
    print("Step %d completed. Time took: %s secs." % (tot_step, diff_time))
    
    # save model at every 500 steps
    if ((tot_step+1) % 500) == 0:
        print("-----------------------------------------------------------------")
        print("Average Disc_fake loss: %f" % (np.mean(avg_disc_fake_loss))) 
        print("Average Disc_real loss: %f" % (np.mean(avg_disc_real_loss))) 
        print("Average GAN loss: %f" % (np.mean(avg_GAN_loss)))
        print("-----------------------------------------------------------------")
        discriminator.trainable = False
        generator.trainable = False
        # predict on fixed_noise
        fixed_noise_generate = generator.predict(noise)
        step_num = str(tot_step).zfill(4)
        save_img_batch(fixed_noise_generate,img_save_dir+step_num+"fixed_image.png")
        generator.save(save_model_dir+str(tot_step)+"_GENERATOR_weights_and_arch2.hdf5")
        discriminator.save(save_model_dir+str(tot_step)+"_DISCRIMINATOR_weights_and_arch2.hdf5")
# Out:
# Begin step:  0
# WARNING:tensorflow:From /Users/justin/anaconda3/lib/python3.7/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Disc: real loss: 1.104766 fake loss: 2.187299
# GAN loss: 2.357179
# Step 0 completed. Time took: 8 secs.
# Begin step:  1
# Disc: real loss: 0.972448 fake loss: 0.401468
# GAN loss: 3.621054
# Step 1 completed. Time took: 2 secs.
# Begin step:  2
# Disc: real loss: 1.011069 fake loss: 0.401076
# GAN loss: 3.113695
# Step 2 completed. Time took: 2 secs.
# Begin step:  3
# Disc: real loss: 0.694269 fake loss: 0.414117
# GAN loss: 3.580277
# Step 3 completed. Time took: 2 secs.
# Begin step:  4
# Disc: real loss: 0.681102 fake loss: 0.438065
# GAN loss: 3.701082
# Step 4 completed. Time took: 2 secs.
# Begin step:  5
# Disc: real loss: 0.630402 fake loss: 0.380040
# GAN loss: 3.368291
# Step 5 completed. Time took: 2 secs.
# Begin step:  6
# Disc: real loss: 0.428599 fake loss: 0.501816
# GAN loss: 5.208063
# Step 6 completed. Time took: 2 secs.
# Begin step:  7
# Disc: real loss: 0.660097 fake loss: 0.444132
# GAN loss: 2.225091
# Step 7 completed. Time took: 2 secs.
# Begin step:  8
# Disc: real loss: 0.844681 fake loss: 1.168862
# GAN loss: 8.326841
# Step 8 completed. Time took: 2 secs.
# Begin step:  9
# Disc: real loss: 0.531320 fake loss: 1.151730
# GAN loss: 11.364240
# Step 9 completed. Time took: 2 secs.
# Begin step:  10
# Disc: real loss: 0.684414 fake loss: 0.798741
# GAN loss: 5.956972
# Step 10 completed. Time took: 2 secs.
# Begin step:  11
# Disc: real loss: 0.699982 fake loss: 0.425340
# GAN loss: 2.403887
# Step 11 completed. Time took: 2 secs.
# Begin step:  12
# Disc: real loss: 0.623590 fake loss: 0.571185
# GAN loss: 6.206444
# Step 12 completed. Time took: 2 secs.
# Begin step:  13
# Disc: real loss: 0.530360 fake loss: 0.714442
# GAN loss: 5.579252
# Step 13 completed. Time took: 2 secs.
# Begin step:  14
# Disc: real loss: 0.420796 fake loss: 0.351569
# GAN loss: 2.050860
# Step 14 completed. Time took: 2 secs.
# Begin step:  15
# Disc: real loss: 0.544162 fake loss: 0.988824
# GAN loss: 9.829378
# Step 15 completed. Time took: 2 secs.
# Begin step:  16
# Disc: real loss: 1.366376 fake loss: 1.027672
# GAN loss: 8.143023
# Step 16 completed. Time took: 2 secs.
# Begin step:  17
# Disc: real loss: 1.186118 fake loss: 0.545838
# GAN loss: 3.548245
# Step 17 completed. Time took: 2 secs.
# Begin step:  18
# Disc: real loss: 1.074458 fake loss: 1.052372
# GAN loss: 7.721778
# Step 18 completed. Time took: 2 secs.
# Begin step:  19
# Disc: real loss: 0.715533 fake loss: 1.212699
# GAN loss: 9.913567
# Step 19 completed. Time took: 2 secs.
# Begin step:  20
# Disc: real loss: 0.606706 fake loss: 0.781527
# GAN loss: 5.197755
# Step 20 completed. Time took: 2 secs.
# Begin step:  21
# Disc: real loss: 0.516909 fake loss: 0.478795
# GAN loss: 3.955999
# Step 21 completed. Time took: 2 secs.
# Begin step:  22
# Disc: real loss: 0.454494 fake loss: 0.434478
# GAN loss: 2.291350
# Step 22 completed. Time took: 2 secs.
# Begin step:  23
# Disc: real loss: 0.550391 fake loss: 0.775048
# GAN loss: 8.449553
# Step 23 completed. Time took: 2 secs.
# Begin step:  24
# Disc: real loss: 0.669091 fake loss: 1.048860
# GAN loss: 8.414654
# Step 24 completed. Time took: 2 secs.
# Begin step:  25
# Disc: real loss: 0.522336 fake loss: 0.662845
# GAN loss: 4.133766
# Step 25 completed. Time took: 2 secs.
# Begin step:  26
# Disc: real loss: 0.540177 fake loss: 0.599411
# GAN loss: 5.378858
# Step 26 completed. Time took: 2 secs.
# Begin step:  27
# Disc: real loss: 0.496879 fake loss: 0.452680
# GAN loss: 3.183095
# Step 27 completed. Time took: 2 secs.
# Begin step:  28
# Disc: real loss: 0.432739 fake loss: 0.429512
# GAN loss: 4.589432
# Step 28 completed. Time took: 2 secs.
# Begin step:  29
# Disc: real loss: 0.493246 fake loss: 0.388799
# GAN loss: 2.139217
# Step 29 completed. Time took: 3 secs.
# Begin step:  30
# Disc: real loss: 0.399681 fake loss: 0.671574
# GAN loss: 7.828409
# Step 30 completed. Time took: 2 secs.
# Begin step:  31
# Disc: real loss: 1.189857 fake loss: 0.612880
# GAN loss: 2.759054
# Step 31 completed. Time took: 2 secs.
# Begin step:  32
# Disc: real loss: 0.984372 fake loss: 1.258492
# GAN loss: 9.676683
# Step 32 completed. Time took: 2 secs.
# Begin step:  33
# Disc: real loss: 0.527698 fake loss: 1.329127
# GAN loss: 12.801546
# Step 33 completed. Time took: 2 secs.
# Begin step:  34
# Disc: real loss: 0.759286 fake loss: 0.792715
# GAN loss: 5.491944
# Step 34 completed. Time took: 2 secs.
# Begin step:  35
# Disc: real loss: 0.791018 fake loss: 0.571769
# GAN loss: 4.025135
# Step 35 completed. Time took: 2 secs.
# Begin step:  36
# Disc: real loss: 0.711962 fake loss: 0.531781
# GAN loss: 3.488449
# Step 36 completed. Time took: 2 secs.
# Begin step:  37
# Disc: real loss: 0.431273 fake loss: 0.693360
# GAN loss: 7.937235
# Step 37 completed. Time took: 2 secs.
# Begin step:  38
# Disc: real loss: 1.077421 fake loss: 0.686597
# GAN loss: 3.604070
# Step 38 completed. Time took: 2 secs.
# Begin step:  39
# Disc: real loss: 0.749228 fake loss: 0.928846
# GAN loss: 7.777066
# Step 39 completed. Time took: 2 secs.
# Begin step:  40
# Disc: real loss: 0.527859 fake loss: 0.816606
# GAN loss: 8.301284
# Step 40 completed. Time took: 2 secs.
# Begin step:  41
# Disc: real loss: 0.785285 fake loss: 0.416162
# GAN loss: 1.982955
# Step 41 completed. Time took: 2 secs.
# Begin step:  42
# Disc: real loss: 0.517066 fake loss: 1.097819
# GAN loss: 7.892000
# Step 42 completed. Time took: 2 secs.
# Begin step:  43
# Disc: real loss: 1.031734 fake loss: 0.757988
# GAN loss: 4.596889
# Step 43 completed. Time took: 2 secs.
# Begin step:  44
# Disc: real loss: 0.570637 fake loss: 0.435577
# GAN loss: 2.691870
# Step 44 completed. Time took: 2 secs.
# Begin step:  45
# Disc: real loss: 0.531610 fake loss: 0.457686
# GAN loss: 4.143368
# Step 45 completed. Time took: 2 secs.
# Begin step:  46
# Disc: real loss: 0.404735 fake loss: 0.431508
# GAN loss: 2.226047
# Step 46 completed. Time took: 2 secs.
# Begin step:  47
# Disc: real loss: 0.469511 fake loss: 0.756505
# GAN loss: 7.352777
# Step 47 completed. Time took: 2 secs.
# Begin step:  48
# Disc: real loss: 1.082522 fake loss: 0.598759
# GAN loss: 2.806853
# Step 48 completed. Time took: 2 secs.
# Begin step:  49
# Disc: real loss: 0.633447 fake loss: 0.466955
# GAN loss: 4.027411
# Step 49 completed. Time took: 2 secs.
# Begin step:  50
# Disc: real loss: 0.476256 fake loss: 0.629929
# GAN loss: 4.162117
# Step 50 completed. Time took: 2 secs.
# Begin step:  51
# Disc: real loss: 0.364191 fake loss: 0.427486
# GAN loss: 1.821665
# Step 51 completed. Time took: 2 secs.
# Begin step:  52
# Disc: real loss: 0.388041 fake loss: 0.636647
# GAN loss: 4.615211
# Step 52 completed. Time took: 2 secs.
# Begin step:  53
# Disc: real loss: 0.672871 fake loss: 0.493828
# GAN loss: 1.772119
# Step 53 completed. Time took: 2 secs.
# Begin step:  54
# Disc: real loss: 0.437957 fake loss: 0.955625
# GAN loss: 5.432256
# Step 54 completed. Time took: 2 secs.
# Begin step:  55
# Disc: real loss: 0.969104 fake loss: 0.435123
# GAN loss: 1.744941
# Step 55 completed. Time took: 2 secs.
# Begin step:  56
# Disc: real loss: 0.479942 fake loss: 1.395175
# GAN loss: 8.517153
# Step 56 completed. Time took: 2 secs.
# Begin step:  57
# Disc: real loss: 1.309939 fake loss: 0.663912
# GAN loss: 3.997131
# Step 57 completed. Time took: 2 secs.
# Begin step:  58
# Disc: real loss: 0.639832 fake loss: 0.703327
# GAN loss: 4.705046
# Step 58 completed. Time took: 2 secs.
# Begin step:  59
# Disc: real loss: 0.429877 fake loss: 0.591954
# GAN loss: 4.203262
# Step 59 completed. Time took: 2 secs.
# Begin step:  60
# Disc: real loss: 0.533213 fake loss: 0.369892
# GAN loss: 2.116465
# Step 60 completed. Time took: 2 secs.
# Begin step:  61
# Disc: real loss: 0.455104 fake loss: 0.567797
# GAN loss: 3.988383
# Step 61 completed. Time took: 2 secs.
# Begin step:  62
# Disc: real loss: 0.749164 fake loss: 0.414893
# GAN loss: 2.161633
# Step 62 completed. Time took: 2 secs.
# Begin step:  63
# Disc: real loss: 0.460416 fake loss: 0.486688
# GAN loss: 2.898989
# Step 63 completed. Time took: 2 secs.
# Begin step:  64
# Disc: real loss: 0.386657 fake loss: 0.401927
# GAN loss: 2.567946
# Step 64 completed. Time took: 2 secs.
# Begin step:  65
# Disc: real loss: 0.412516 fake loss: 0.407312
# GAN loss: 2.367961
# Step 65 completed. Time took: 2 secs.
# Begin step:  66
# Disc: real loss: 0.430451 fake loss: 0.368142
# GAN loss: 1.125799
# Step 66 completed. Time took: 2 secs.
# Begin step:  67
# Disc: real loss: 0.435604 fake loss: 0.442018
# GAN loss: 2.973138
# Step 67 completed. Time took: 2 secs.
# Begin step:  68
# Disc: real loss: 0.395708 fake loss: 0.420353
# GAN loss: 1.187135
# Step 68 completed. Time took: 2 secs.
# Begin step:  69
# Disc: real loss: 0.389854 fake loss: 0.515636
# GAN loss: 3.537791
# Step 69 completed. Time took: 2 secs.
# Begin step:  70
# Disc: real loss: 0.696891 fake loss: 0.446125
# GAN loss: 2.957782
# Step 70 completed. Time took: 2 secs.
# Begin step:  71
# Disc: real loss: 0.429460 fake loss: 0.354806
# GAN loss: 2.251796
# Step 71 completed. Time took: 2 secs.
# Begin step:  72
# Disc: real loss: 0.437828 fake loss: 0.537016
# GAN loss: 5.267925
# Step 72 completed. Time took: 2 secs.
# Begin step:  73
# Disc: real loss: 1.442208 fake loss: 1.401358
# GAN loss: 5.578576
# Step 73 completed. Time took: 2 secs.
# Begin step:  74
# Disc: real loss: 0.844775 fake loss: 0.441763
# GAN loss: 2.958215
# Step 74 completed. Time took: 2 secs.
# Begin step:  75
# Disc: real loss: 0.487155 fake loss: 0.788294
# GAN loss: 4.511737
# Step 75 completed. Time took: 2 secs.
# Begin step:  76
# Disc: real loss: 0.568342 fake loss: 0.411939
# GAN loss: 2.849356
# Step 76 completed. Time took: 2 secs.
# Begin step:  77
# Disc: real loss: 0.419820 fake loss: 0.431942
# GAN loss: 3.012897
# Step 77 completed. Time took: 2 secs.
# Begin step:  78
# Disc: real loss: 0.494199 fake loss: 0.330897
# GAN loss: 2.772009
# Step 78 completed. Time took: 2 secs.
# Begin step:  79
# Disc: real loss: 0.384881 fake loss: 0.359988
# GAN loss: 2.583825
# Step 79 completed. Time took: 2 secs.
# Begin step:  80
# Disc: real loss: 0.446572 fake loss: 0.548348
# GAN loss: 3.990040
# Step 80 completed. Time took: 2 secs.
# Begin step:  81
# Disc: real loss: 0.721030 fake loss: 0.421601
# GAN loss: 2.380376
# Step 81 completed. Time took: 2 secs.
# Begin step:  82
# Disc: real loss: 0.452179 fake loss: 0.340817
# GAN loss: 2.946343
# Step 82 completed. Time took: 2 secs.
# Begin step:  83
# Disc: real loss: 0.387112 fake loss: 0.367170
# GAN loss: 2.322133
# Step 83 completed. Time took: 2 secs.
# Begin step:  84
# Disc: real loss: 0.427579 fake loss: 0.656546
# GAN loss: 4.362864
# Step 84 completed. Time took: 2 secs.
# Begin step:  85
# Disc: real loss: 0.885201 fake loss: 0.390480
# GAN loss: 2.334112
# Step 85 completed. Time took: 2 secs.
# Begin step:  86
# Disc: real loss: 0.403268 fake loss: 0.364720
# GAN loss: 2.614907
# Step 86 completed. Time took: 2 secs.
# Begin step:  87
# Disc: real loss: 0.370067 fake loss: 0.347779
# GAN loss: 2.021192
# Step 87 completed. Time took: 2 secs.
# Begin step:  88
# Disc: real loss: 0.467819 fake loss: 0.392575
# GAN loss: 1.728844
# Step 88 completed. Time took: 2 secs.
# Begin step:  89
# Disc: real loss: 0.366291 fake loss: 0.354235
# GAN loss: 0.765893
# Step 89 completed. Time took: 2 secs.
# Begin step:  90
# Disc: real loss: 0.400577 fake loss: 0.960248
# GAN loss: 8.055895
# Step 90 completed. Time took: 2 secs.
# Begin step:  91
# Disc: real loss: 2.282455 fake loss: 0.496139
# GAN loss: 2.310351
# Step 91 completed. Time took: 2 secs.
# Begin step:  92
# Disc: real loss: 0.590219 fake loss: 1.564028
# GAN loss: 7.533646
# Step 92 completed. Time took: 2 secs.
# Begin step:  93
# Disc: real loss: 2.175572 fake loss: 0.484046

# %%
def generate_images(generator, save_dir):
    noise = gen_noise(batch_size,noise_shape)
    fake_data_X = generator.predict(noise)
    print("Displaying generated images")
    plt.figure(figsize=(16,16))
    gs1 = gridspec.GridSpec(4, 4)
    gs1.update(wspace=0, hspace=0)
    rand_indices = np.random.choice(fake_data_X.shape[0],16,replace=False)
    for i in range(16):
        ax1 = plt.subplot(gs1[i])
        ax1.set_aspect('equal')
        rand_index = rand_indices[i]
        image = fake_data_X[rand_index, :,:,:]
        fig = plt.imshow(denorm_img(image))
        plt.axis('off')
        fig.axes.get_xaxis().set_visible(False)
        fig.axes.get_yaxis().set_visible(False)
    plt.tight_layout()
    plt.savefig(save_dir+str(time.time())+"_GENERATEDimage.png",bbox_inches='tight',pad_inches=0)
    plt.show()

generate_images(generator, img_save_dir)

# %%
disc_real_loss = np.array(avg_disc_real_loss)
disc_fake_loss = np.array(avg_disc_fake_loss)
GAN_loss = np.array(avg_GAN_loss)

# Plot the losses vs training steps
plt.figure(figsize=(16,8))
plt.plot(range(0,num_steps), disc_real_loss, label="Discriminator Loss - Real")
plt.plot(range(0,num_steps), disc_fake_loss, label="Discriminator Loss - Fake")
plt.plot(range(0,num_steps), GAN_loss, label="Generator Loss")
plt.xlabel('Steps')
plt.ylabel('Loss')
plt.legend()
plt.title('GAN Loss')
plt.grid(True)
plt.show()

# %%
#Generating GIF from PNGs
import imageio
# create a list of PNGs
generated_images = [img_save_dir+str(x).zfill(4)+"_image.png" for x in range(0,num_steps,100)]

# %%
images = []
for filename in generated_images:
    images.append(imageio.imread(filename))

imageio.mimsave(img_save_dir+'movie.gif', images)

# %%
from IPython.display import Image
with open("images/movie.gif",'rb') as f:
    display(Image(data=f.read(), format='png'))
